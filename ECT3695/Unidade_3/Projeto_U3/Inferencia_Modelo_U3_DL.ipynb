# %% [markdown]
# <a href="https://colab.research.google.com/github/rikdantas/Algoritmos-Estruturas-Dados-I/blob/main/ECT3695/Unidade_3/Projeto_U3/Inferencia_Modelo_U3_DL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Testando o modelo já treinado

# %%
# !pip install ultralytics -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 913.5/913.5 kB 11.3 MB/s eta 0:00:00

# %%
from ultralytics import YOLO
import cv2

# Carregar o modelo YOLO treinado
model = YOLO("best.pt")

# Caminhos dos vídeos
input_video_path = "video_teste1.mp4"  # Vídeo de entrada
output_video_path = "video_teste1_segmentado.mp4"  # Vídeo de saída

# Carregar o vídeo
cap = cv2.VideoCapture(input_video_path)

# Configurar o vídeo de saída com a mesma taxa de quadros e resolução do vídeo de entrada
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(output_video_path, fourcc, cap.get(cv2.CAP_PROP_FPS),
                      (int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)), int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))))

# Processar cada quadro do vídeo
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Realizar a segmentação no frame
    results = model(frame, conf=0.4, imgsz=640)

    # Extrair o frame com segmentação anotada
    annotated_frame = results[0].plot()  # `plot()` retorna a imagem com a segmentação aplicada

    # Escrever o frame anotado no vídeo de saída
    out.write(annotated_frame)

# Liberar os objetos
cap.release()
out.release()

print(f"Vídeo com segmentação salvo em: {output_video_path}")
# Out:
# 0: 384x640 3 cows, 65.8ms
# Speed: 2.7ms preprocess, 65.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cows, 46.0ms
# Speed: 3.8ms preprocess, 46.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cows, 44.0ms
# Speed: 3.5ms preprocess, 44.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cows, 48.2ms
# Speed: 3.3ms preprocess, 48.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cows, 40.2ms
# Speed: 3.6ms preprocess, 40.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cows, 38.7ms
# Speed: 3.4ms preprocess, 38.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cows, 39.7ms
# Speed: 3.4ms preprocess, 39.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cows, 39.7ms
# ...

# %%
from ultralytics import YOLO
import cv2

# Carregar o modelo YOLO treinado
model = YOLO("best.pt")

# Caminhos dos vídeos
input_video_path = "video_teste2.mp4"  # Vídeo de entrada
output_video_path = "video_teste2_segmentado.mp4"  # Vídeo de saída

# Carregar o vídeo
cap = cv2.VideoCapture(input_video_path)

# Configurar o vídeo de saída com a mesma taxa de quadros e resolução do vídeo de entrada
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(output_video_path, fourcc, cap.get(cv2.CAP_PROP_FPS),
                      (int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)), int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))))

# Processar cada quadro do vídeo
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Realizar a segmentação no frame
    results = model(frame, max_det=1, imgsz=640)

    # Extrair o frame com segmentação anotada
    annotated_frame = results[0].plot()  # `plot()` retorna a imagem com a segmentação aplicada

    # Escrever o frame anotado no vídeo de saída
    out.write(annotated_frame)

# Liberar os objetos
cap.release()
out.release()

print(f"Vídeo com segmentação salvo em: {output_video_path}")
# Out:
# 0: 384x640 1 cow, 56.2ms
# Speed: 2.3ms preprocess, 56.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cow, 40.6ms
# Speed: 3.6ms preprocess, 40.6ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cow, 40.2ms
# Speed: 5.0ms preprocess, 40.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cow, 40.7ms
# Speed: 3.6ms preprocess, 40.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cow, 43.2ms
# Speed: 3.8ms preprocess, 43.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cow, 43.6ms
# Speed: 3.5ms preprocess, 43.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cow, 42.2ms
# Speed: 3.6ms preprocess, 42.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cow, 42.9ms
# ...

# %%
from ultralytics import YOLO
import cv2

# Carregar o modelo YOLO treinado
model = YOLO("best.pt")

# Caminhos dos vídeos
input_video_path = "video_teste3.mp4"  # Vídeo de entrada
output_video_path = "video_teste3_segmentado.mp4"  # Vídeo de saída

# Carregar o vídeo
cap = cv2.VideoCapture(input_video_path)

# Configurar o vídeo de saída com a mesma taxa de quadros e resolução do vídeo de entrada
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(output_video_path, fourcc, cap.get(cv2.CAP_PROP_FPS),
                      (int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)), int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))))

# Processar cada quadro do vídeo
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Realizar a segmentação no frame
    results = model(frame, conf=0.4, imgsz=640)

    # Extrair o frame com segmentação anotada
    annotated_frame = results[0].plot()  # `plot()` retorna a imagem com a segmentação aplicada

    # Escrever o frame anotado no vídeo de saída
    out.write(annotated_frame)

# Liberar os objetos
cap.release()
out.release()

print(f"Vídeo com segmentação salvo em: {output_video_path}")
# Out:
# 0: 384x640 9 cows, 64.7ms
# Speed: 3.5ms preprocess, 64.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cows, 44.5ms
# Speed: 3.2ms preprocess, 44.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cows, 43.4ms
# Speed: 3.4ms preprocess, 43.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cows, 44.5ms
# Speed: 3.6ms preprocess, 44.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cows, 42.0ms
# Speed: 11.6ms preprocess, 42.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cows, 41.2ms
# Speed: 5.2ms preprocess, 41.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cows, 40.6ms
# Speed: 8.3ms preprocess, 40.6ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cows, 43.0ms
# ...

# %%
from ultralytics import YOLO
import cv2

# Carregar o modelo YOLO treinado
model = YOLO("best.pt")

# Caminhos dos vídeos
input_video_path = "video_teste4.mp4"  # Vídeo de entrada
output_video_path = "video_teste4_segmentado.mp4"  # Vídeo de saída

# Carregar o vídeo
cap = cv2.VideoCapture(input_video_path)

# Configurar o vídeo de saída com a mesma taxa de quadros e resolução do vídeo de entrada
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(output_video_path, fourcc, cap.get(cv2.CAP_PROP_FPS),
                      (int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)), int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))))

# Processar cada quadro do vídeo
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Realizar a segmentação no frame
    results = model(frame, conf=0.4, imgsz=640)

    # Extrair o frame com segmentação anotada
    annotated_frame = results[0].plot()  # `plot()` retorna a imagem com a segmentação aplicada

    # Escrever o frame anotado no vídeo de saída
    out.write(annotated_frame)

# Liberar os objetos
cap.release()
out.release()

print(f"Vídeo com segmentação salvo em: {output_video_path}")
# Out:
# 0: 384x640 4 cows, 49.4ms
# Speed: 2.1ms preprocess, 49.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cows, 39.3ms
# Speed: 3.1ms preprocess, 39.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cows, 38.0ms
# Speed: 3.0ms preprocess, 38.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cows, 38.0ms
# Speed: 3.0ms preprocess, 38.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cows, 38.5ms
# Speed: 3.3ms preprocess, 38.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cows, 37.6ms
# Speed: 3.4ms preprocess, 37.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cows, 37.4ms
# Speed: 3.4ms preprocess, 37.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cows, 37.8ms
# ...
